# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# %%
plt.plot(x, y);
plt.title('Simple Line Plot');
plt.xlabel('X-axis label');
plt.ylabel('Y-axis label');
plt.grid(True)

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr']
revenue = [100, 200, 300, 500]

# %%
plt.figure(figsize=(10, 6))
plt.bar(months, revenue)
plt.title('Monthly Revenue Bar Chart');
plt.xlabel('Months');
plt.ylabel('Revenue');

# %%
marks50 = np.random.randint(0, 100, 50)
marks50
# Out:
# array([63, 11, 51, 52, 39, 58, 95, 72,  1, 81, 76,  6, 13, 75, 34, 25, 87,
#        26, 44, 73, 55, 86, 77, 36, 10, 59, 17, 50, 48, 81, 62, 79, 50, 37,
#         4, 26,  6, 89, 81, 74, 57, 53, 31, 39, 49, 14,  7, 66, 89, 43],
#       dtype=int32)

# %%
plt.hist(marks50, bins=15)
# Out:
# (array([5., 3., 2., 3., 1., 3., 4., 5., 4., 4., 1., 5., 5., 2., 3.]),
#  array([ 1.        ,  7.26666667, 13.53333333, 19.8       , 26.06666667,
#         32.33333333, 38.6       , 44.86666667, 51.13333333, 57.4       ,
#         63.66666667, 69.93333333, 76.2       , 82.46666667, 88.73333333,
#         95.        ]),
#  <BarContainer object of 15 artists>)

# %%
heights = [65, 70, 68, 72, 66]
weights = [150, 160, 155, 180, 145]

# %%
plt.scatter(heights, weights)
plt.title('Heights vs. Weights Scatter Plot')
plt.xlabel('Height (inches)')
plt.ylabel('Weight (pounds)')
# Out:
# Text(0, 0.5, 'Weight (pounds)')

# %%
days = [1, 2, 3, 4, 5]
original_price = [10, 20, 25, 30, 40]
predicted_price = [8, 21, 25, 28, 38]

# %%
plt.plot(days, original_price, 'g-o', label='Original Price')
plt.plot(days, predicted_price, 'r-o', label='Predicted Price')
plt.legend()
plt.title('Plot with legends')
plt.xlabel('Weekdays')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
# First subplot - Original Price
plt.subplot(3, 1, 1)
plt.plot(days, original_price, 'b-o', label='Original Price')
plt.title('Original prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

# Second subplot - Predicted Price
plt.subplot(3, 1, 2)
plt.plot(days, predicted_price, 'r-o', label='Predicted Price')
plt.title('Predicted prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

# Third subplot - Difference between Original & Predicted Prices
price_difference = [o - p for o, p in zip(original_price, predicted_price)]
plt.subplot(3, 1, 3)
plt.bar(days, price_difference, color='purple', label='Price Difference')
plt.title('Difference between Original & Predicted Prices')
plt.xlabel('Days')
plt.ylabel('Price Difference')
plt.legend()

plt.tight_layout()
plt.savefig('example_prediction.png', dpi=300) # save the image
