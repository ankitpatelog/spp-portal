# %%
import numpy as np

# %% [markdown]
# ## create and read

# %%
arr1 = np.array([1,2,3,4,5])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
randarr = np.random.rand(2,3,2)
randarr
# Out:
# array([[[0.60142226, 0.41030537],
#         [0.57503939, 0.53546946],
#         [0.64378795, 0.78885969]],
#
#        [[0.40653798, 0.56453101],
#         [0.75842633, 0.77786792],
#         [0.72101903, 0.02412197]]])
